# %%
import requests
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify

import sqlite3
pd.set_option('display.max_columns', None)
import math

# %%
url = "https://developer.nrel.gov/api/alt-fuel-stations/v1.csv?country=US&fuel_type=ELEC&api_key=64cNIGU4nf2hwT5JO6PLbkxqp0IDkhbjvcCKbsWw"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
df = pd.read_csv(url)
df = df.rename(columns=lambda x: x.strip().replace(" ", "_"))
# Out:
# /Users/zhr47/opt/anaconda3/envs/NewPythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (6,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
database_path = "Project2.db"

engine = create_engine(f"sqlite:///{database_path}?check_same_thread=False")

base = automap_base()
base.prepare(engine, reflect=True)

# %%
connection = sqlite3.connect("Project2.db")

# %%
df.to_sql("EVData",connection)

# %%
database_path = "Project2.db"
engine = create_engine(f"sqlite:///{database_path}?check_same_thread=False")
base = automap_base()
base.prepare(engine, reflect=True)

connection = sqlite3.connect("Project2.db")

# %%
#make sure to remove below before turning in Project

# %%
# Choose the table we wish to use
table = base.classes.EVData

# %%
session = Session(engine)
results = session.query(table.EV_Network).all()
session.close()

# %%
print(results)
# Out:
# [('Non-Networked',), ('Greenlots',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Volta',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Volta',), ('Non-Networked',), ('Non-Networked',), ('EV Connect',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('EV Connect',), ('Non-Networked',), ('Non-Networked',), ('EV Connect',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Greenlots',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',),  ...

# %%
session = Session(engine)
results = session.query(table.State).all()
session.close()

# %%
evnetwork = {}
for EV_Network in results:
    if (EV_Network[0] in evnetwork):
        evnetwork[EV_Network[0]]+=1
    else:
        evnetwork[EV_Network[0]] = 1

# %%
print(results)
# Out:
# [('Non-Networked',), ('Greenlots',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Volta',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Volta',), ('Non-Networked',), ('Non-Networked',), ('EV Connect',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('EV Connect',), ('Non-Networked',), ('Non-Networked',), ('EV Connect',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Greenlots',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('Non-Networked',), ('ChargePoint Network',), ('ChargePoint Network',), ('ChargePoint Network',),  ...
